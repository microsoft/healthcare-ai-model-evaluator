# %% [markdown]
# ## Dependencies

# %%
import os
import sys

sys.path.append(os.path.join(os.getcwd(), '..'))

# %%
# %load_ext autoreload
# %autoreload 2

import json
import tempfile
from functools import partial

import pandas as pd
from loguru import logger

from medbench.aml import AzureML
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load data

# %% [markdown]
# ### `mtsamples-gpt4-summarization`
#
# There are two jsonl files for this dataset, but both of them have a lot of overlap. So for the purpose of this notebook, we will merge both files into a single dataframe.

# %%
aml = AzureML.connect_to_registry(registry_name="azureml-1p")

# %%
rounding_output = "rounding_output.jsonl"
output_clean = "output-clean-gpt4.jsonl"

# %%
mtsamples_readings_output_df = aml.get_dataset(
    name="mtsamples-gpt4-summarization", version="latest", read_folder_jsonl=True, target_jsonl=rounding_output
)

print(mtsamples_readings_output_df.shape)
mtsamples_readings_output_df.head()
# Out:
# 2024-10-31 16:29:00.851 | DEBUG    | medbench.aml:get_dataset:130 - Downloading rounding_output.jsonl to temporary directory `/tmp/tmpnl55mwc_`...
# 2024-10-31 16:29:05.902 | INFO     | medbench.aml:get_dataset:135 - Reading rounding_output.jsonl as a pandas DataFrame.
# (1252, 6)
# /home/lschettini/dev/medbench/medbench-data/notebooks/../medbench/aml.py:138: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   return pd.read_json(jsonl_str, lines=True)
#                                             Keywords  \
# 0  pediatrics - neonatal, 1-year-old, naps, mama,...
# 1  radiology, 2-d study, doppler, tricuspid regur...
# 2  radiology, 2-d m-mode, doppler, aortic valve, ...
# 3  radiology, 2-d, doppler, echocardiogram, annul...
# 4  radiology, 2-d echocardiogram, cardiac functio...
#
#                                          Description  \
# 0     Health maintenance exam for 1-year-old female.
# 1  Normal left ventricle, moderate biatrial enlar...
# 2                               2-D M-Mode. Doppler.
# 3                                 2-D Echocardiogram
# 4                                 2-D Echocardiogram
#
#                      Filename  \
# 0   1-year-old Exam - H&P.txt
# 1             2-D Doppler.txt
# 2  2-D Echocardiogram - 1.txt
# 3  2-D Echocardiogram - 2.txt
# 4  2-D Echocardiogram - 3.txt
#
#                                        Clinical_Note      Medical_Specialty  \
# 0  CHIEF COMPLAINT: This 1-year-old female presen...  Pediatrics - Neonatal
# 1  2-D STUDY1. Mild aortic stenosis, widely calci...              Radiology
# 2  2-D M-MODE:  1. Left atrial enlargement with l...              Radiology
# 3  COMMENTS:1. The left ventricular cavity size a...              Radiology
# 4  2-D ECHOCARDIOGRAMMultiple views of the heart ...              Radiology
#
#                                         output_gpt-4
# 0  {\n  "History": "This 1-year-old female patien...
# 1  {\n  "History": "The patient's chart does not ...
# 2  {\n  "History": "The patient's chart does not ...
# 3  {\n  "History": "The patient's chart does not ...
# 4  {\n  "History": "No relevant medical history, ...

# %%
mtsamples_clean_output_df = aml.get_dataset(
    name="mtsamples-gpt4-summarization", version="latest", read_folder_jsonl=True, target_jsonl=output_clean
)

print(mtsamples_clean_output_df.shape)
mtsamples_clean_output_df.head()
# Out:
# 2024-10-31 16:29:07.230 | DEBUG    | medbench.aml:get_dataset:130 - Downloading output-clean-gpt4.jsonl to temporary directory `/tmp/tmp1d28lp34`...
# 2024-10-31 16:29:09.734 | INFO     | medbench.aml:get_dataset:135 - Reading output-clean-gpt4.jsonl as a pandas DataFrame.
# (1255, 6)
# /home/lschettini/dev/medbench/medbench-data/notebooks/../medbench/aml.py:138: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   return pd.read_json(jsonl_str, lines=True)
#                                             Keywords  \
# 0   pediatrics - neonatal, 1-year-old, naps, mama...
# 1   radiology, 2-d study, doppler, tricuspid regu...
# 2   radiology, 2-d m-mode, doppler, aortic valve,...
# 3   radiology, 2-d, doppler, echocardiogram, annu...
# 4   radiology, 2-d echocardiogram, cardiac functi...
#
#                                          Description  \
# 0     Health maintenance exam for 1-year-old female.
# 1   Normal left ventricle, moderate biatrial enla...
# 2                               2-D M-Mode. Doppler.
# 3                                 2-D Echocardiogram
# 4                                 2-D Echocardiogram
#
#                      Filename  \
# 0   1-year-old Exam - H&P.txt
# 1             2-D Doppler.txt
# 2  2-D Echocardiogram - 1.txt
# 3  2-D Echocardiogram - 2.txt
# 4  2-D Echocardiogram - 3.txt
#
#                                        Clinical_Note      Medical_Specialty  \
# 0  CHIEF COMPLAINT: This 1-year-old female presen...  Pediatrics - Neonatal
# 1  2-D STUDY1. Mild aortic stenosis, widely calci...              Radiology
# 2  2-D M-MODE:  1. Left atrial enlargement with l...              Radiology
# 3  COMMENTS:1. The left ventricular cavity size a...              Radiology
# 4  2-D ECHOCARDIOGRAMMultiple views of the heart ...              Radiology
#
#                                         output_gpt-4
# 0  {\n"indication": "Routine well child care, Acu...
# 1  {\n"indication": "Mild aortic stenosis, Mild l...
# 2  {\n"indication": "Left atrial enlargement, Mil...
# 3  {\n"indication": "Cardiac evaluation",\n"indic...
# 4  {\n"indication": "Routine check-up",\n"indicat...

# %% [markdown]
# To ensure more matches, we clean the texts before merging

# %%
for col in mtsamples_clean_output_df.columns:
    mtsamples_clean_output_df[col] = mtsamples_clean_output_df[col].str.strip()
    mtsamples_readings_output_df[col] = mtsamples_readings_output_df[col].str.strip()

# %%
mt_samples_summarization = pd.merge(
    mtsamples_readings_output_df,
    mtsamples_clean_output_df,
    on=["Keywords", "Description", "Filename", "Medical_Specialty"],
    how="outer",
    suffixes=("_rounding", "_clean"),
)

print(mt_samples_summarization.shape)
mt_samples_summarization.head()
# Out:
# (1266, 8)
#                                             Keywords  \
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  allergy / immunology, asthma, complete physica...
# 2  allergy / immunology, chronic glossitis, xeros...
# 3  allergy / immunology, keflex, acute allergic r...
# 4  allergy / immunology, sinusitis, cephalgia, si...
#
#                                          Description  \
# 0  A 23-year-old white female presents with compl...
# 1  A female for a complete physical and follow up...
# 2  Chronic glossitis, xerostomia, probable enviro...
# 3  Acute allergic reaction, etiology uncertain, h...
# 4  Functional endoscopic sinus surgery with left ...
#
#                                    Filename  \
# 0                     Allergic Rhinitis.txt
# 1                    Followup on Asthma.txt
# 2               Evaluation of Allergies.txt
# 3            Allergy Evaluation Consult.txt
# 4  Ethmoidectomy and Mastoid Antrostomy.txt
#
#                               Clinical_Note_rounding     Medical_Specialty  \
# 0  SUBJECTIVE: This 23-year-old white female pres...  Allergy / Immunology
# 1  SUBJECTIVE:  This is a 42-year-old white femal...  Allergy / Immunology
# 2  HISTORY: A 55-year-old female presents self-re...  Allergy / Immunology
# 3  HISTORY:  A 34-year-old male presents today se...  Allergy / Immunology
# 4  PREOPERATIVE DIAGNOSES:1. Chronic sinusitis.2....  Allergy / Immunology
#
#                                output_gpt-4_rounding  \
# 0  {\n  "History": "The patient is a 23-year-old ...
# 1  {\n  "History": "The patient is a 42-year-old ...
# 2  {\n  "History": "The patient is a 55-year-old ...
# 3  {\n  "History": "The patient is a 34-year-old ...
# 4  {\n  "History": "The patient is a 50-year-old ...
#
#                                  Clinical_Note_clean  \
# 0  SUBJECTIVE: This 23-year-old white female pres...
# 1  SUBJECTIVE:  This is a 42-year-old white femal...
# 2  HISTORY: A 55-year-old female presents self-re...
# 3  HISTORY:  A 34-year-old male presents today se...
# 4  PREOPERATIVE DIAGNOSES:1. Chronic sinusitis.2....
#
#                                   output_gpt-4_clean
# 0  {\n"indication": "Allergic rhinitis",\n"indica...
# 1  {\n"indication": "Asthma exacerbation, Allergi...
# 2  {\n"indication": "Evaluation and treatment of ...
# 3  {\n"indication": "Acute allergic reaction, Ren...
# 4  {\n"indication": "Chronic sinusitis and sinus ...

# %% [markdown]
# Note we do not merge over `Clinical_Note`. The reason is that one single entry has a different value despite all other columns' values being the same:

# %%
not_nan = mt_samples_summarization[
    (mt_samples_summarization["Clinical_Note_rounding"].notna())
    & (mt_samples_summarization["Clinical_Note_clean"].notna())
]

not_nan[not_nan["Clinical_Note_rounding"] != not_nan["Clinical_Note_clean"]]
# Out:
#                                                Keywords  \
# 1083  pediatrics - neonatal, 1-year-old, naps, mama,...
#
#                                          Description  \
# 1083  Health maintenance exam for 1-year-old female.
#
#                        Filename  \
# 1083  1-year-old Exam - H&P.txt
#
#                                  Clinical_Note_rounding  \
# 1083  CHIEF COMPLAINT: This 1-year-old female presen...
#
#           Medical_Specialty  \
# 1083  Pediatrics - Neonatal
#
#                                   output_gpt-4_rounding  \
# 1083  {\n  "History": "This 1-year-old female patien...
#
#                                     Clinical_Note_clean  \
# 1083  CHIEF COMPLAINT: This 1-year-old female presen...
#
#                                      output_gpt-4_clean
# 1083  {\n"indication": "Routine well child care, Acu...

# %% [markdown]
# The difference is only a punctuation mark, and for that reason we take the clinical note from the `output-clean-gpt4.jsonl` file:

# %%
def select_clinical_note(
    row,
    clinical_note_columns: list[str] = [
        "Clinical_Note_rounding",
        "Clinical_Note_clean",
    ],
    priority_clinical_note="Clinical_Note_clean",
):
    clinical_note_columns_isna = [
        isinstance(row[col], float) for col in clinical_note_columns
    ]

    if all(clinical_note_columns_isna):
        raise ValueError("Both clinical notes are missing")

    if clinical_note_columns_isna[0]:
        return row[clinical_note_columns[1]]
    elif clinical_note_columns_isna[1]:
        return row[clinical_note_columns[0]]
    else:
        return row[priority_clinical_note]


mt_samples_summarization["Clinical_Note"] = mt_samples_summarization.apply(
    select_clinical_note, axis=1
)

mt_samples_summarization.shape
# Out:
# (1266, 9)

# %%
mt_samples_summarization.drop(columns=["Clinical_Note_rounding", "Clinical_Note_clean"], inplace=True)

mt_samples_summarization.shape
# Out:
# (1266, 7)

# %%
mt_samples_summarization.fillna("", inplace=True)

# %%
mt_samples_summarization
# Out:
#                                                Keywords  \
# 0     allergy / immunology, allergic rhinitis, aller...
# 1     allergy / immunology, asthma, complete physica...
# 2     allergy / immunology, chronic glossitis, xeros...
# 3     allergy / immunology, keflex, acute allergic r...
# 4     allergy / immunology, sinusitis, cephalgia, si...
# ...                                                 ...
# 1261  radiology, silver chloride biopotential electr...
# 1262  radiology, supraclavicular, cervical adenopath...
# 1263  radiology, transcatheter infusion of papaverin...
# 1264  radiology, tumor cells, concomitant chemoradio...
# 1265  radiology, ventricular hypertrophy, normal wal...
#
#                                             Description  \
# 0     A 23-year-old white female presents with compl...
# 1     A female for a complete physical and follow up...
# 2     Chronic glossitis, xerostomia, probable enviro...
# 3     Acute allergic reaction, etiology uncertain, h...
# 4     Functional endoscopic sinus surgery with left ...
# ...                                                 ...
# 1261  Abnormal electronystagmogram demonstrating pro...
# 1262  A 68-year-old white male with recently diagnos...
# 1263  Diagnostic cerebral angiogram and transcathete...
# 1264  Concomitant chemoradiotherapy for curative int...
# 1265  Echocardiographic examination. Borderline left...
#
#                                       Filename     Medical_Specialty  \
# 0                        Allergic Rhinitis.txt  Allergy / Immunology
# 1                       Followup on Asthma.txt  Allergy / Immunology
# 2                  Evaluation of Allergies.txt  Allergy / Immunology
# 3               Allergy Evaluation Consult.txt  Allergy / Immunology
# 4     Ethmoidectomy and Mastoid Antrostomy.txt  Allergy / Immunology
# ...                                        ...                   ...
# 1261                   Electronystagmogram.txt             Radiology
# 1262                          CT Chest - 2.txt             Radiology
# 1263         Diagnostic Cerebral Angiogram.txt             Radiology
# 1264         Concomitant Chemoradiotherapy.txt             Radiology
# 1265                      Echocardiography.txt             Radiology
#
#                                   output_gpt-4_rounding  \
# 0     {\n  "History": "The patient is a 23-year-old ...
# 1     {\n  "History": "The patient is a 42-year-old ...
# 2     {\n  "History": "The patient is a 55-year-old ...
# 3     {\n  "History": "The patient is a 34-year-old ...
# 4     {\n  "History": "The patient is a 50-year-old ...
# ...                                                 ...
# 1261  {\n  "History": "No relevant medical history, ...
# 1262  {\n  "History": "The patient is a 68-year-old ...
# 1263  {\n  "History": "The patient is a 13-year-old ...
# 1264
# 1265  {\n  "History": "The patient's chart does not ...
#
#                                      output_gpt-4_clean  \
# 0     {\n"indication": "Allergic rhinitis",\n"indica...
# 1     {\n"indication": "Asthma exacerbation, Allergi...
# 2     {\n"indication": "Evaluation and treatment of ...
# 3     {\n"indication": "Acute allergic reaction, Ren...
# 4     {\n"indication": "Chronic sinusitis and sinus ...
# ...                                                 ...
# 1261  {\n"indication": "Vestibular Dysfunction",\n"i...
# 1262  {\n"indication": "Adenocarcinoma",\n"indicatio...
# 1263  {\n"indication": "Postoperative check angiogra...
# 1264  {\n"indication": "Cancer",\n"indication_icd10"...
# 1265  {\n"indication": "CVA",\n"indication_icd10": "...
#
#                                           Clinical_Note
# 0     SUBJECTIVE: This 23-year-old white female pres...
# 1     SUBJECTIVE:  This is a 42-year-old white femal...
# 2     HISTORY: A 55-year-old female presents self-re...
# 3     HISTORY:  A 34-year-old male presents today se...
# 4     PREOPERATIVE DIAGNOSES:1. Chronic sinusitis.2....
# ...                                                 ...
# 1261  PROCEDURE: This tracing was obtained utilizing...
# 1262  CLINICAL HISTORY:  A 68-year-old white male wi...
# 1263  EXAM:1. Diagnostic cerebral angiogram.2. Trans...
# 1264  CONCOMITANT CHEMORADIOTHERAPY FOR CURATIVE INT...
# 1265  REASON FOR EXAM: CVA.INDICATIONS:  CVA.This is...
#
# [1266 rows x 7 columns]

# %% [markdown]
# #### Process gpt-4 outputs

# %%
def try_json_loads(value: str):
    try:
        return json.loads(value)
    except json.JSONDecodeError:
        return {}
    
mt_samples_summarization["output_gpt-4_rounding"] = mt_samples_summarization["output_gpt-4_rounding"].apply(try_json_loads)
mt_samples_summarization["output_gpt-4_clean"] = mt_samples_summarization["output_gpt-4_clean"].apply(try_json_loads)

# %%
rounding_keys = set()
clean_keys = set()

# jsons can have different keys, find all possibilities:
for i, row in mt_samples_summarization.iterrows():
    rounding_keys.update(row["output_gpt-4_rounding"].keys())
    clean_keys.update(row["output_gpt-4_clean"].keys())

len(rounding_keys), len(clean_keys)
# Out:
# (11, 11)

# %%
target_source_output_key_map = {}

rounding_keys_map = {key.lower(): key for key in rounding_keys}
clean_keys_map = {key.lower(): key for key in clean_keys}

for clean_key, key in clean_keys_map.items():
    target_source_output_key_map[clean_key] = {"output_gpt-4_clean": key}

for clean_key, key in rounding_keys_map.items():
    if clean_key not in target_source_output_key_map:
        target_source_output_key_map[clean_key] = {}

    target_source_output_key_map[clean_key]["output_gpt-4_rounding"] = key

target_source_output_key_map
# Out:
# {'findings': {'output_gpt-4_clean': 'findings',
#   'output_gpt-4_rounding': 'Findings'},
#  'diagnosis_icd10': {'output_gpt-4_clean': 'diagnosis_icd10',
#   'output_gpt-4_rounding': 'diagnosis_icd10'},
#  'nurse': {'output_gpt-4_clean': 'nurse'},
#  'indication_icd10': {'output_gpt-4_clean': 'indication_icd10',
#   'output_gpt-4_rounding': 'indication_icd10'},
#  'patient': {'output_gpt-4_clean': 'patient'},
#  'loinc': {'output_gpt-4_clean': 'LOINC', 'output_gpt-4_rounding': 'LOINC'},
#  'indication': {'output_gpt-4_clean': 'indication',
#   'output_gpt-4_rounding': 'indication'},
#  'pharmacy': {'output_gpt-4_clean': 'pharmacy'},
#  'results': {'output_gpt-4_clean': 'results',
#   'output_gpt-4_rounding': 'results'},
#  'rxnorm': {'output_gpt-4_clean': 'RxNorm', 'output_gpt-4_rounding': 'RxNorm'},
#  'summary': {'output_gpt-4_clean': 'summary'},
#  'history': {'output_gpt-4_rounding': 'History'},
#  'plan': {'output_gpt-4_rounding': 'Plan'},
#  'cpt': {'output_gpt-4_rounding': 'CPT'},
#  'currentcondition': {'output_gpt-4_rounding': 'CurrentCondition'}}

# %%
OutputKeyMapping = dict[str, dict[str, str]]

def explode_gpt4_outputs(
    row,
    output_key_mapping: OutputKeyMapping,
    # gpt4_output_columns: list[str] = ["output_gpt-4_rounding", "output_gpt-4_clean"],
):
    mapped_outputs = {}
    for target_output_key_suffix, output_key_map in output_key_mapping.items():
        for gpt4_key, source_output_key in output_key_map.items():
            if gpt4_key in row and source_output_key in row[gpt4_key]:
                mapped_outputs[f"{gpt4_key}_{target_output_key_suffix}"] = row[gpt4_key][source_output_key]

    return mapped_outputs

mt_samples_summarization["processed_gpt4_outputs"] = mt_samples_summarization.apply(explode_gpt4_outputs, axis=1, output_key_mapping=target_source_output_key_map)
mt_samples_summarization.shape
# Out:
# (1266, 8)

# %%
combined_keys = set()

# jsons can have different keys, find all possibilities:
for i, row in mt_samples_summarization.iterrows():
    combined_keys.update(row["processed_gpt4_outputs"].keys())

len(combined_keys)
# Out:
# 22

# %%
gpt4_output_df = pd.json_normalize(mt_samples_summarization["processed_gpt4_outputs"], max_level=0)
gpt4_output_df.shape
# Out:
# (1266, 22)

# %%
# Combine two dataframes
mt_samples_summarization = pd.concat([mt_samples_summarization, gpt4_output_df], axis=1)
mt_samples_summarization.shape
# Out:
# (1266, 30)

# %%
mt_samples_summarization.head()
# Out:
#                                             Keywords  \
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  allergy / immunology, asthma, complete physica...
# 2  allergy / immunology, chronic glossitis, xeros...
# 3  allergy / immunology, keflex, acute allergic r...
# 4  allergy / immunology, sinusitis, cephalgia, si...
#
#                                          Description  \
# 0  A 23-year-old white female presents with compl...
# 1  A female for a complete physical and follow up...
# 2  Chronic glossitis, xerostomia, probable enviro...
# 3  Acute allergic reaction, etiology uncertain, h...
# 4  Functional endoscopic sinus surgery with left ...
#
#                                    Filename     Medical_Specialty  \
# 0                     Allergic Rhinitis.txt  Allergy / Immunology
# 1                    Followup on Asthma.txt  Allergy / Immunology
# 2               Evaluation of Allergies.txt  Allergy / Immunology
# 3            Allergy Evaluation Consult.txt  Allergy / Immunology
# 4  Ethmoidectomy and Mastoid Antrostomy.txt  Allergy / Immunology
#
#                                output_gpt-4_rounding  \
# 0  {'History': 'The patient is a 23-year-old whit...
# 1  {'History': 'The patient is a 42-year-old whit...
# 2  {'History': 'The patient is a 55-year-old fema...
# 3  {'History': 'The patient is a 34-year-old male...
# 4  {'History': 'The patient is a 50-year-old fema...
#
#                                   output_gpt-4_clean  \
# 0  {'indication': 'Allergic rhinitis', 'indicatio...
# 1  {'indication': 'Asthma exacerbation, Allergic ...
# 2  {'indication': 'Evaluation and treatment of al...
# 3  {'indication': 'Acute allergic reaction, Renal...
# 4  {'indication': 'Chronic sinusitis and sinus ce...
#
#                                        Clinical_Note  \
# 0  SUBJECTIVE: This 23-year-old white female pres...
# 1  SUBJECTIVE:  This is a 42-year-old white femal...
# 2  HISTORY: A 55-year-old female presents self-re...
# 3  HISTORY:  A 34-year-old male presents today se...
# 4  PREOPERATIVE DIAGNOSES:1. Chronic sinusitis.2....
#
#                               processed_gpt4_outputs  \
# 0  {'output_gpt-4_clean_findings': 'Patient prese...
# 1  {'output_gpt-4_clean_findings': 'Patient's ast...
# 2  {'output_gpt-4_clean_findings': 'Patient has a...
# 3  {'output_gpt-4_clean_findings': 'Patient had a...
# 4  {'output_gpt-4_clean_findings': 'Chronic infla...
#
#                          output_gpt-4_clean_findings  \
# 0  Patient presents with allergies, worse than wh...
# 1  Patient's asthma has worsened, requiring daily...
# 2  Patient has a history of fibromyalgia, peptic ...
# 3  Patient had an acute allergic reaction, possib...
# 4  Chronic inflammation within the left maxillary...
#
#                       output_gpt-4_rounding_findings  ...  \
# 0  The patient's symptoms and physical examinatio...  ...
# 1  The patient's recent lab work and cholesterol ...  ...
# 2  The patient was referred for RAST allergy test...  ...
# 3  The patient had an acute allergic reaction, su...  ...
# 4  Functional endoscopic sinus surgery with left ...  ...
#
#                          output_gpt-4_clean_pharmacy  \
# 0  Dispense Zyrtec and Nasonex as prescribed. Che...
# 1  Dispense Flovent 44 mcg, Allegra, Flonase, and...
# 2  No changes in her medication were prescribed u...
# 3  Ensure patient is not prescribed cephalosporin...
# 4  Ensure availability of 1% lidocaine with 1:100...
#
#                output_gpt-4_clean_rxnorm  \
# 0                 [20610, 56946, 314076]
# 1  [688242, 57052, 32968, 20610, 860974]
# 2                                     []
# 3            [1516, 6809, 104959, 20610]
# 4                                 [3498]
#
#                         output_gpt-4_rounding_rxnorm  \
# 0  [{'code': '20610', 'description': 'Zyrtec'}, {...
# 1  [{'code': '4337', 'description': 'Proventil'},...
# 2  [{'code': 'Not provided', 'description': 'Not ...
# 3  [{'code': '159', 'description': 'Atenolol'}, {...
# 4                                                 []
#
#                           output_gpt-4_clean_summary  \
# 0  23-year-old female with history of allergies a...
# 1  42-year-old female with worsening asthma and a...
# 2  55-year-old female presents for evaluation and...
# 3  34-year-old male with a history of renal failu...
# 4  50-year-old female with a history of chronic l...
#
#                        output_gpt-4_rounding_history  \
# 0  The patient is a 23-year-old white female with...
# 1  The patient is a 42-year-old white female with...
# 2  The patient is a 55-year-old female with a his...
# 3  The patient is a 34-year-old male with a histo...
# 4  The patient is a 50-year-old female with a his...
#
#                           output_gpt-4_rounding_plan  \
# 0  The patient will switch from Allegra to Zyrtec...
# 1  The patient's current problems include worseni...
# 2  The patient will follow up after RAST allergy ...
# 3  The patient's main problems are acute allergic...
# 4  The patient's main problems are chronic sinusi...
#
#                            output_gpt-4_rounding_cpt  \
# 0                                                 []
# 1  [{'code': '99214', 'description': 'Office or o...
# 2  [{'code': 'Not provided', 'description': 'Not ...
# 3  [{'code': '86003', 'description': 'Allergen sp...
# 4  [{'code': '31254', 'description': 'Nasal/sinus...
#
#               output_gpt-4_rounding_currentcondition  \
# 0  The patient presents with complaints of worsen...
# 1  The patient's asthma has worsened over the las...
# 2  The patient presents with symptoms of allergie...
# 3  The patient is currently stable, alert, and or...
# 4  The patient was stable during the procedure. S...
#
#   output_gpt-4_clean_results output_gpt-4_rounding_results
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Save dataset

# %%
with tempfile.TemporaryDirectory() as temp_dir_name:
    mt_samples_summarization.to_json(
        os.path.join(temp_dir_name, "unified.jsonl"), orient="records", lines=True
    )

    aml.register_folder_as_dataset(
        folder_path=temp_dir_name,
        dataset_name="mtsamples-gpt4-summarization",
        dataset_description=(
            "GPT-4 summaries from mtsamples dataset.\n\n"
            "Dataset created by running GPT-4 on the mtsamples dataset to generate summaries for several specialties.\n\n"
            "This version of the dataset exposes all model outputs directly as columns. It is otherwise identical to the previous version."
        )
    )
# Out:
# Subtype value SAS has no mapping, use base class DataReferenceCredentialDto.
# Uploading tmp17gseds6 (18.27 MBs): 100%|██████████| 18269693/18269693 [00:10<00:00, 1726619.59it/s]
